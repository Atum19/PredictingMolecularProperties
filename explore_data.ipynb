# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv(f'./data/train.csv')
test = pd.read_csv(f'./data/test.csv')
trn_ob = pd.read_csv(f'./data/train_ob_charges.csv')  # open bab
tst_ob = pd.read_csv(f'./data/test_ob_charges.csv')   # open bab
trn_geom = pd.read_csv(f'./data/train_geom.csv')
tst_geom = pd.read_csv(f'./data/test_geom.csv')
dipole_moments = pd.read_csv(f'./data/dipole_moments.csv')
magnetic_shielding_tensors = pd.read_csv(f'./data/magnetic_shielding_tensors.csv')
mulliken_charges = pd.read_csv(f'./data/mulliken_charges.csv')
potential_energy = pd.read_csv(f'./data/potential_energy.csv')
scal_coup_contrib = pd.read_csv(f'./data/scalar_coupling_contributions.csv')
# sub = pd.read_csv(f'sample_submission.csv')
structures = pd.read_csv(f'./data/structures.csv')

# %%
train.head(20)
# Out:
#     id     molecule_name  atom_index_0  atom_index_1  type  \
# 0    0  dsgdb9nsd_000001             1             0  1JHC
# 1    1  dsgdb9nsd_000001             1             2  2JHH
# 2    2  dsgdb9nsd_000001             1             3  2JHH
# 3    3  dsgdb9nsd_000001             1             4  2JHH
# 4    4  dsgdb9nsd_000001             2             0  1JHC
# 5    5  dsgdb9nsd_000001             2             3  2JHH
# 6    6  dsgdb9nsd_000001             2             4  2JHH
# 7    7  dsgdb9nsd_000001             3             0  1JHC
# 8    8  dsgdb9nsd_000001             3             4  2JHH
# 9    9  dsgdb9nsd_000001             4             0  1JHC
# 10  10  dsgdb9nsd_000002             1             0  1JHN
# 11  11  dsgdb9nsd_000002             1             2  2JHH
# 12  12  dsgdb9nsd_000002             1             3  2JHH
# 13  13  dsgdb9nsd_000002             2             0  1JHN
# 14  14  dsgdb9nsd_000002             2             3  2JHH
# ...

# %%
test.head(10)
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC
# 5  4658152  dsgdb9nsd_000015             3             0  1JHC
# 6  4658153  dsgdb9nsd_000015             3             2  3JHC
# 7  4658154  dsgdb9nsd_000015             3             4  2JHH
# 8  4658155  dsgdb9nsd_000015             3             5  2JHH
# 9  4658156  dsgdb9nsd_000015             4             0  1JHC

# %%
trn_ob.head(20)
# Out:
#     Unnamed: 0     molecule_name  atom_index       eem  mmff94  gasteiger  \
# 0            0  dsgdb9nsd_000001           0 -0.644531  0.0000  -0.077596
# 1            1  dsgdb9nsd_000001           1  0.161131  0.0000   0.019399
# 2            2  dsgdb9nsd_000001           2  0.161132  0.0000   0.019399
# 3            3  dsgdb9nsd_000001           3  0.161134  0.0000   0.019399
# 4            4  dsgdb9nsd_000001           4  0.161134  0.0000   0.019399
# 5            5  dsgdb9nsd_000002           0 -0.931923 -1.0800  -0.451940
# 6            6  dsgdb9nsd_000002           1  0.310640  0.3600   0.150647
# 7            7  dsgdb9nsd_000002           2  0.310641  0.3600   0.150647
# 8            8  dsgdb9nsd_000002           3  0.310643  0.3600   0.150647
# 9            9  dsgdb9nsd_000003           0 -0.636727 -0.8600  -0.576388
# 10          10  dsgdb9nsd_000003           1  0.318363  0.4300   0.288194
# 11          11  dsgdb9nsd_000003           2  0.318363  0.4300   0.288194
# ...

# %%
tst_ob.head()
# Out:
#    Unnamed: 0     molecule_name  atom_index       eem  mmff94  gasteiger  \
# 0           0  dsgdb9nsd_000004           0 -0.140218  -0.177  -0.195499
# 1           1  dsgdb9nsd_000004           1 -0.140218  -0.177  -0.195499
# 2           2  dsgdb9nsd_000004           2  0.140218   0.177   0.195499
# 3           3  dsgdb9nsd_000004           3  0.140218   0.177   0.195499
# 4           4  dsgdb9nsd_000015           0 -0.200372   0.280  -0.018924
#
#         qeq     qtpie  eem2015ha  eem2015hm  eem2015hn  eem2015ba  eem2015bm  \
# 0  0.162134 -0.104823   0.186739  -0.244665  -0.126079   0.188397  -0.232962
# 1  0.162134 -0.104823   0.186739  -0.244665  -0.126079   0.188397  -0.232962
# 2 -0.162134  0.104823  -0.186739   0.244665   0.126079  -0.188397   0.232962
# 3 -0.162134  0.104823  -0.186739   0.244665   0.126079  -0.188397   0.232962
# 4 -0.438607  0.348798   0.462935  -0.319256  -0.257585   0.347919  -0.405719
#
#    eem2015bn  error
# 0  -0.126054      0
# 1  -0.126054      0
# ...

# %%
trn_geom.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant  num_atoms  flatness_metric  bond_angle_plane  \
# 0                   84.8076          5         0.443763         52.084336
# 1                  -11.2570          5         0.443763         73.351369
# 2                  -11.2548          5         0.443763         39.073646
# 3                  -11.2543          5         0.443763         20.124275
# 4                   84.8074          5         0.443763         50.858953
#
#    bond_angle_axis
# 0        34.460723
# 1         0.804151
# 2        44.696643
# 3        44.160491
# 4        36.069061

# %%
angles = pd.read_csv(f'./data/angles.csv')

# %%
angles.head(10)
# Out:
#       molecule_name  atom_index_0  atom_index_1 shortest_path_atoms  \
# 0  dsgdb9nsd_000001             1             0                 NaN
# 1  dsgdb9nsd_000001             1             2                   C
# 2  dsgdb9nsd_000001             1             3                   C
# 3  dsgdb9nsd_000001             1             4                   C
# 4  dsgdb9nsd_000001             2             0                 NaN
# 5  dsgdb9nsd_000001             2             3                   C
# 6  dsgdb9nsd_000001             2             4                   C
# 7  dsgdb9nsd_000001             3             0                 NaN
# 8  dsgdb9nsd_000001             3             4                   C
# 9  dsgdb9nsd_000001             4             0                 NaN
#
#    shortest_path_n_bonds  cosinus  dihedral
# 0                      1      NaN       NaN
# 1                      2 -0.33329       NaN
# 2                      2 -0.33333       NaN
# ...

# %%
dipole_moments.head(10)
# Out:
#       molecule_name       X       Y       Z
# 0  dsgdb9nsd_000001  0.0000  0.0000  0.0000
# 1  dsgdb9nsd_000002 -0.0002  0.0000  1.6256
# 2  dsgdb9nsd_000003  0.0000  0.0000 -1.8511
# 3  dsgdb9nsd_000005  0.0000  0.0000 -2.8937
# 4  dsgdb9nsd_000007  0.0000  0.0000  0.0000
# 5  dsgdb9nsd_000008  0.6506 -1.3801 -0.0002
# 6  dsgdb9nsd_000009  0.7156  0.0004 -0.0004
# 7  dsgdb9nsd_000010  3.8266  0.0000 -0.0001
# 8  dsgdb9nsd_000011  2.3605  1.0119  0.0004
# 9  dsgdb9nsd_000012 -3.6612  0.7058  0.0009

# %%
magnetic_shielding_tensors.head(10)
# Out:
#       molecule_name  atom_index        XX      YX      ZX      XY        YY  \
# 0  dsgdb9nsd_000001           0  195.3150  0.0000 -0.0001  0.0000  195.3170
# 1  dsgdb9nsd_000001           1   31.3410 -1.2317  4.0544 -1.2317   28.9546
# 2  dsgdb9nsd_000001           2   31.5814  1.2173 -4.1474  1.2173   28.9036
# 3  dsgdb9nsd_000001           3   31.5172  4.1086  1.2723  4.1088   33.9068
# 4  dsgdb9nsd_000001           4   31.4029 -4.0942 -1.1793 -4.0944   34.0776
# 5  dsgdb9nsd_000002           0  275.6350  0.0003  0.0133  0.0003  275.6360
# 6  dsgdb9nsd_000002           1   31.2593  5.6126 -2.1025  5.6136   37.4364
# 7  dsgdb9nsd_000002           2   31.0341 -5.4827 -2.0299 -5.4837   37.6618
# 8  dsgdb9nsd_000002           3   40.7507 -0.1300  4.1318 -0.1300   27.9413
# 9  dsgdb9nsd_000003           0  310.0960  0.0000  0.0000  0.0000  355.7730
#
#        ZY      XZ      YZ        ZZ
# 0  0.0007 -0.0001  0.0007  195.3170
# 1 -1.7173  4.0546 -1.7173   34.0861
# ...

# %%
mulliken_charges.head(50)
# Out:
#        molecule_name  atom_index  mulliken_charge
# 0   dsgdb9nsd_000001           0        -0.535689
# 1   dsgdb9nsd_000001           1         0.133921
# 2   dsgdb9nsd_000001           2         0.133922
# 3   dsgdb9nsd_000001           3         0.133923
# 4   dsgdb9nsd_000001           4         0.133923
# 5   dsgdb9nsd_000002           0        -0.707143
# 6   dsgdb9nsd_000002           1         0.235712
# 7   dsgdb9nsd_000002           2         0.235712
# 8   dsgdb9nsd_000002           3         0.235720
# 9   dsgdb9nsd_000003           0        -0.589706
# 10  dsgdb9nsd_000003           1         0.294853
# 11  dsgdb9nsd_000003           2         0.294853
# 12  dsgdb9nsd_000005           0        -0.049655
# 13  dsgdb9nsd_000005           1        -0.188473
# 14  dsgdb9nsd_000005           2         0.238128
# 15  dsgdb9nsd_000007           0        -0.345672
# 16  dsgdb9nsd_000007           1        -0.345672
# 17  dsgdb9nsd_000007           2         0.115222
# ...

# %%
potential_energy.head(20)

# %%
scal_coup_contrib.head(50)

# %%
structures.head(50)
# Out:
#        molecule_name  atom_index atom         x         y         z
# 0   dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1   dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2   dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3   dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4   dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397
# 5   dsgdb9nsd_000002           0    N -0.040426  1.024108  0.062564
# 6   dsgdb9nsd_000002           1    H  0.017257  0.012545 -0.027377
# 7   dsgdb9nsd_000002           2    H  0.915789  1.358745 -0.028758
# 8   dsgdb9nsd_000002           3    H -0.520278  1.343532 -0.775543
# 9   dsgdb9nsd_000003           0    O -0.034360  0.977540  0.007602
# 10  dsgdb9nsd_000003           1    H  0.064766  0.020572  0.001535
# 11  dsgdb9nsd_000003           2    H  0.871790  1.300792  0.000693
# 12  dsgdb9nsd_000004           0    C  0.599539  0.000000  1.000000
# ...
